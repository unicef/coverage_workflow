# %% [markdown]
# </center><img src="coverage_workflow_image.png"  width="1000" height="300"/></center>

# %%
# import required python libraries
#import geopandas as gpd  # for geo-data structure
import numpy as np  # for some operation better done with numpy
import matplotlib.pyplot as plt  # for creating plots
#import shapely.geometry  # for geometry data crunching
#from shapely.geometry import Point  # specifically for point geometry data manipulation
#import keplergl
#from keplergl import KeplerGl
import datacompy
import pandas as pd
crs = {'init': 'epsg:4326'}
#from shapely.geometry import Point
import mpl_toolkits

# %%
# bring in the 3 to 4 different coverage dataset from FB, GSMA, ITU and Ericsson as well as the master school_geolocation

# %%
d_f = pd.read_csv('./data/CostaRica_Connectivity.csv',low_memory=False,encoding='utf-8')
d_i = pd.read_csv('./data/costa_rica_school_coverage_ITU.csv',low_memory=False,encoding='utf-8')
d_e = pd.read_csv('./data/CR_20210301-20210531_Ericsson.csv',low_memory=False,encoding='utf-8')
#d_g = pd.read_csv('./data/GSMA_RW_Schools_mobile_coverage_v1.csv',low_memory=False,encoding='utf-8')
s_master = pd.read_csv('./data/costa_rica_school_master.csv',low_memory=False,encoding='utf-8')

# %%
d_f.head(2)
# Out:
#         tile_bigint  clean_lat  clean_lon     school_id  source_school_id  \
# 0  1204370302011735  10.371701 -83.727492  G_CRI_000081              5807
# 1  1194590661480958   9.622965 -84.509157  G_CRI_000457               675
#
#                                    uuid     country      source  \
# 0  a35c8f68-84f3-3c6d-bea2-b6bfc8b95525  Costa Rica  government
# 1  d0f361a9-f9c9-348e-995c-ccb831078e9f  Costa Rica  government
#
#                   name education_level  ...  missing_school_name_flag_scale  \
# 0  NOCTURNO DE CARIARI       secondary  ...                               1
# 1           MONTELIMAR         Primary  ...                               1
#
#   missing_education_level_flag_scale school_density_outlier_flag_scale  \
# 0                                  1                                 1
# 1                                  1                                 1
#
#    dq_score source_timestamp  master_timestamp  school_archive percent_2g  \
# 0       0.8           7/1/21           42:48.4              No       2.94
# 1       1.0           7/1/21           42:48.4              No       2.94
#
#   percent_3g  percent_4g
# 0      76.47       20.59
# 1      77.45       19.61
#
# [2 rows x 51 columns]

# %%
d_e.rename(columns={'SCHOOL_CODE':'giga_school_id', 'SCHOOL_NAME':'school_name', '2G_coverage':'2G_quality','3G_coverage':'3G_quality','4G_coverage':'4G_quality'}, inplace=True)
d_i.rename(columns={'name':'school_name'}, inplace=True)
d_f.rename(columns={'school_id': 'giga_school_id','name':'school_name'}, inplace=True)

# %%
# cross-profiles the sources with master data for completeness and correctness

# %%
# create a separate dfs
master = s_master.copy()
fb = d_f.copy()
ec = d_e.copy()
itu = d_i.copy()
#gsma = d_g.copy()
# for facebook
cross_profile_fb_master = datacompy.Compare(
master,
fb,
join_columns='giga_school_id',  
df1_name='Master', 
df2_name='Facebook'
)
#for ericsson
cross_profile_e_master = datacompy.Compare(
master,
ec,
join_columns='giga_school_id',  
df1_name='Master', 
df2_name='Ericsson'
)
# for ITU
cross_profile_itu_master = datacompy.Compare(
master,
itu,
join_columns='giga_school_id',  
df1_name='Master', 
df2_name='ITU'
)
print(cross_profile_fb_master.report())
print(cross_profile_e_master.report())
print(cross_profile_itu_master.report())
#print(cross_profile_gsma_master.report())
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns  Rows
# 0    Master       14  4598
# 1  Facebook       51  4598
#
# Column Summary
# --------------
#
# Number of columns in common: 12
# Number of columns in Master but not in Facebook: 2
# Number of columns in Facebook but not in Master: 39
#
# Row Summary
# -----------
#
# Matched on: giga_school_id
# Any duplicates on match values: No
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 4,598
# Number of rows in Master but not in Facebook: 0
# Number of rows in Facebook but not in Master: 0
#
# Number of rows with some compared columns unequal: 4,598
# Number of rows with all compared columns equal: 0
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 1
# Number of columns compared with all values equal: 11
# Total number of values which compare unequal: 4,598
#
# Columns with Unequal Values or Types
# ------------------------------------
#
#          Column Master dtype Facebook dtype  # Unequal  Max Diff  # Null Diff
# 0  connectivity       object         object       4598         0            0
#
# Sample Rows with Unequal Values
# -------------------------------
#
#      giga_school_id connectivity (Master) connectivity (Facebook)
# 4148   G_CRI_004149                   YES                     Yes
# 3310   G_CRI_003311                   YES                     Yes
# 1917   G_CRI_001918                   YES                     Yes
# 2402   G_CRI_002403                   YES                     Yes
# 1195   G_CRI_001196                   YES                     Yes
# 3744   G_CRI_003745                   YES                     Yes
# 3014   G_CRI_003015                   YES                     Yes
# 2621   G_CRI_002622                   YES                     Yes
# 54     G_CRI_000055                   YES                     Yes
# 92     G_CRI_000093                   YES                     Yes
#
#
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns  Rows
# 0    Master       14  4598
# 1  Ericsson       27  4598
#
# Column Summary
# --------------
#
# Number of columns in common: 3
# Number of columns in Master but not in Ericsson: 11
# Number of columns in Ericsson but not in Master: 24
#
# Row Summary
# -----------
#
# Matched on: giga_school_id
# Any duplicates on match values: No
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 4,598
# Number of rows in Master but not in Ericsson: 0
# Number of rows in Ericsson but not in Master: 0
#
# Number of rows with some compared columns unequal: 0
# Number of rows with all compared columns equal: 4,598
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 0
# Number of columns compared with all values equal: 3
# Total number of values which compare unequal: 0
#
#
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns  Rows
# 0    Master       14  4598
# 1       ITU       59  4598
#
# Column Summary
# --------------
#
# Number of columns in common: 13
# Number of columns in Master but not in ITU: 1
# Number of columns in ITU but not in Master: 46
#
# Row Summary
# -----------
#
# Matched on: giga_school_id
# Any duplicates on match values: No
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 4,598
# Number of rows in Master but not in ITU: 0
# Number of rows in ITU but not in Master: 0
#
# Number of rows with some compared columns unequal: 4,598
# Number of rows with all compared columns equal: 0
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 1
# Number of columns compared with all values equal: 12
# Total number of values which compare unequal: 4,598
#
# Columns with Unequal Values or Types
# ------------------------------------
#
#          Column Master dtype ITU dtype  # Unequal  Max Diff  # Null Diff
# 0  connectivity       object    object       4598         0            0
#
# Sample Rows with Unequal Values
# -------------------------------
#
#      giga_school_id connectivity (Master) connectivity (ITU)
# 1533   G_CRI_001534                   YES                Yes
# 1020   G_CRI_001021                   YES                Yes
# 2927   G_CRI_002928                   YES                Yes
# 2469   G_CRI_002470                   YES                Yes
# 2313   G_CRI_002314                   YES                Yes
# 460    G_CRI_000461                   YES                Yes
# 2404   G_CRI_002405                   YES                Yes
# 1404   G_CRI_001405                   YES                Yes
# 3796   G_CRI_003797                    NO                 No
# 1264   G_CRI_001265                    NO                 No

# %%
# some colunm names standardization

# %%
#d_e.rename(columns={'SCHOOL_CODE':'school_id', 'SCHOOL_NAME':'school_name'}, inplace=True)
#d_i.rename(columns={'giga_schoo': 'giga_school_id','source_sch':'school_id', 'name':'school_name'}, inplace=True)
#d_g.rename(columns={'giga_schoo': 'giga_school_id'}, inplace=True)

# %%
# cross-profiles the sources with master data for completeness and correctness

# %%
# they usually don't come with "coverage" colunms, we create it at source level using the following codes

# %%
#d_e['coverage'] = np.where((d_e['2G_coverage']== 'None') & (d_e['3G_coverage']== 'None')& (d_e['4G_coverage']== 'None'), 'NO', 'YES')
d_f['coverage'] = np.where((d_f['percent_2g'].isnull()) & (d_f['percent_3g'].isnull())& (d_f['percent_4g'].isnull()), 'NO', 'YES')
d_f['coverage'] = np.where((d_f['percent_2g']<=0) & (d_f['percent_3g']<=0) & (d_f['percent_4g']<=0), 'NO', 'YES')
d_i['coverage'] = np.where((d_i['2G'].isnull()) & (d_i['3G'].isnull())& (d_i['4G'].isnull()), 'NO', 'YES')
d_i['coverage'] = np.where((d_i['2G']<=0) & (d_i['3G']<=0) & (d_i['4G']<=0), 'NO', 'YES')

# %%
# create the 2G, 3G and 4G coverage columns with binary values at source level using the following codes

# %%
d_f['2G_coverage'] = np.where((d_f['percent_2g'] > 0), 'YES', 'NO')
d_f['3G_coverage'] = np.where((d_f['percent_3g'] > 0), 'YES', 'NO')
d_f['4G_coverage'] = np.where((d_f['percent_4g'] > 0), 'YES', 'NO')

# %%
d_i['2G_coverage'] = np.where((d_i['2G'] >=1), 'YES', 'NO')
d_i['3G_coverage'] = np.where((d_i['3G'] == 1), 'YES', 'NO')
d_i['4G_coverage'] = np.where((d_i['4G'] ==1), 'YES', 'NO')

# %%
#d_e.rename(columns={'2G_coverage':'2G_coverage_quality', '3G_coverage':'3G_coverage_quality', '4G_coverage': '4G_coverage_quality'}, inplace=True)

# %%
# they usually don't come with "coverage_type" colunms, we create it at source level using the following function and codes

# %%
def coverage_type(df):
    if df['4G_coverage'] == 'YES':
        return "4G"
    elif df['3G_coverage'] == 'YES':
        return "3G"
    elif df['2G_coverage'] == 'YES':
        return "2G"
    else:
        return "None"

# %%
d_f['coverage_type'] = d_f.apply((lambda x: coverage_type(x)),axis=1)
#d_e['coverage_type'] = d_e.apply((lambda x: coverage_type(x)),axis=1)
d_i['coverage_type'] = d_i.apply((lambda x: coverage_type(x)),axis=1)

# %%
d_e.head(1)
# Out:
#   giga_school_id     school_name school_region  LATITUDE  LONGITUDE  \
# 0   G_CRI_000040  C.T.P. DE JACO         Urban  9.627762 -84.623144
#
#   connectivity                                  uuid Coverage Coverage_type  \
# 0          YES  973a0ff3-de89-3d61-9cbf-7e1aa3ff480b      YES            4G
#
#   2G_quality  ... 2G_Best_Coverage_provider 3G_Best_Coverage_provider  \
# 0       Fair  ...                     Claro                     Claro
#
#   4G_Best_Coverage_provider 5G_Best_Coverage_provider 2G_coverage_present  \
# 0                  movistar                      None                 YES
#
#   3G_coverage_present 4G_coverage_present 5G_coverage_present  \
# 0                 YES                 YES                  No
#
#   Distance_to_nearest_tower Data_Source
# 0                        -1    Ericsson
#
# [1 rows x 27 columns]

# %%
d_e.rename(columns={'2G_coverage_present':'2G_coverage', '3G_coverage_present':'3G_coverage','4G_coverage_present':'4G_coverage', 'Coverage':'coverage', 'Coverage_type':'coverage_type'}, inplace=True)

# %%
# isolating the needed colunms from the rest

# %%
features = ['giga_school_id','coverage','coverage_type','2G_coverage','3G_coverage','4G_coverage']

# %%
d_fc = d_f[features]
#d_ec = d_e[features]
d_it = d_i[features]
d_ec = d_e[features]

# %%
# more sanity checks for nan on giga_school_id

# %%
d_fc = d_fc[d_fc['giga_school_id'].notna()]
#d_ec = d_ec[d_ec['giga_school_id'].notna()]
d_it = d_it[d_it['giga_school_id'].notna()]
d_ec = d_ec[d_ec['giga_school_id'].notna()]

# %%
# visually comparing the sources for matches and mismatches across the columns

# %%
df_all = pd.concat([d_fc.set_index('giga_school_id'), d_ec.set_index('giga_school_id'),d_it.set_index('giga_school_id')], 
                   axis='columns', keys=['Facebook', 'Ericsson', 'ITU'])
df_all.head()
# Out:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#              Facebook                                                    \
#              coverage coverage_type 2G_coverage 3G_coverage 4G_coverage
# G_CRI_000001      YES            4G         YES         YES         YES
# G_CRI_000002      YES            4G         YES         YES         YES
# G_CRI_000003      YES            4G         YES         YES         YES
# G_CRI_000004      YES            4G         YES         YES         YES
# G_CRI_000005      YES            4G         YES         YES         YES
#
#              Ericsson                                                    \
#              coverage coverage_type 2G_coverage 3G_coverage 4G_coverage
# G_CRI_000001      YES            4G         YES         YES         YES
# G_CRI_000002      YES            4G         YES         YES         YES
# G_CRI_000003      YES            4G         YES         YES         YES
# G_CRI_000004      YES            4G         YES         YES         YES
# G_CRI_000005      YES            4G         YES         YES         YES
#
#                   ITU
#              coverage coverage_type 2G_coverage 3G_coverage 4G_coverage
# G_CRI_000001      YES            4G         YES         YES         YES
# G_CRI_000002      YES            4G         YES         YES         YES
# G_CRI_000003      YES            4G         YES         YES         YES
# G_CRI_000004      YES            4G         YES         YES         YES
# G_CRI_000005      YES            4G         YES         YES         YES

# %%
d_ec.head()
# Out:
#   giga_school_id coverage coverage_type 2G_coverage 3G_coverage 4G_coverage
# 0   G_CRI_000040      YES            4G         YES         YES         YES
# 1   G_CRI_000077      YES            4G         YES         YES         YES
# 2   G_CRI_000078      YES            4G         YES         YES         YES
# 3   G_CRI_000100      YES            4G         YES         YES         YES
# 4   G_CRI_000168      YES            4G         YES         YES         YES

# %%
df_final = df_all.swaplevel(axis='columns')[d_fc.columns[1:]]
df_final.head()
# Out:
#              coverage               coverage_type              2G_coverage  \
#              Facebook Ericsson  ITU      Facebook Ericsson ITU    Facebook
# G_CRI_000001      YES      YES  YES            4G       4G  4G         YES
# G_CRI_000002      YES      YES  YES            4G       4G  4G         YES
# G_CRI_000003      YES      YES  YES            4G       4G  4G         YES
# G_CRI_000004      YES      YES  YES            4G       4G  4G         YES
# G_CRI_000005      YES      YES  YES            4G       4G  4G         YES
#
#                            3G_coverage               4G_coverage
#              Ericsson  ITU    Facebook Ericsson  ITU    Facebook Ericsson  ITU
# G_CRI_000001      YES  YES         YES      YES  YES         YES      YES  YES
# G_CRI_000002      YES  YES         YES      YES  YES         YES      YES  YES
# G_CRI_000003      YES  YES         YES      YES  YES         YES      YES  YES
# G_CRI_000004      YES  YES         YES      YES  YES         YES      YES  YES
# G_CRI_000005      YES  YES         YES      YES  YES         YES      YES  YES

# %%
def highlight_diff(data, color='lightcoral'):
    attr = 'background-color: {}'.format(color)
    other = data.xs('Facebook', axis='columns', level=-1)
    return pd.DataFrame(np.where(data.ne(other, level=0), attr, ''),
                        index=data.index, columns=data.columns)

#df_final.style.apply(highlight_diff, axis=None)

# %%
# coverage comparison report

# %%
# create a separate dfs
fbc = d_fc.copy()
#ecc = d_ec.copy()
ituc = d_it.copy()
ecc = d_ec.copy()

# Facebook&ITU
cross_profile_fb_itu = datacompy.Compare(
fbc,
ituc,
join_columns='giga_school_id',  
df1_name='Facebook', 
df2_name='ITU'
)

cross_profile_facebook_ec = datacompy.Compare(
fbc,
ecc,
join_columns='giga_school_id',  
df1_name='Facebook', 
df2_name='GSMA'
)


#print(cross_profile_fb_ec.report())
print(cross_profile_fb_itu.report())
#print(cross_profile_Ericsson_itu.report())
print(cross_profile_facebook_ec.report())
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns  Rows
# 0  Facebook        6  4598
# 1       ITU        6  4598
#
# Column Summary
# --------------
#
# Number of columns in common: 6
# Number of columns in Facebook but not in ITU: 0
# Number of columns in ITU but not in Facebook: 0
#
# Row Summary
# -----------
#
# Matched on: giga_school_id
# Any duplicates on match values: No
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 4,598
# Number of rows in Facebook but not in ITU: 0
# Number of rows in ITU but not in Facebook: 0
#
# Number of rows with some compared columns unequal: 2,744
# Number of rows with all compared columns equal: 1,854
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 5
# Number of columns compared with all values equal: 1
# Total number of values which compare unequal: 9,820
#
# Columns with Unequal Values or Types
# ------------------------------------
#
#           Column Facebook dtype ITU dtype  # Unequal  Max Diff  # Null Diff
# 3    2g_coverage         object    object       1653         0            0
# 4    3g_coverage         object    object       1764         0            0
# 1    4g_coverage         object    object       2553         0            0
# 2       coverage         object    object       1297         0            0
# 0  coverage_type         object    object       2553         0            0
#
# Sample Rows with Unequal Values
# -------------------------------
#
#      giga_school_id coverage_type (Facebook) coverage_type (ITU)
# 1373   G_CRI_003263                       4G                None
# 2165   G_CRI_004220                       4G                None
# 364    G_CRI_002583                       4G                None
# 2444   G_CRI_003239                       4G                None
# 1152   G_CRI_003719                       4G                  3G
# 1962   G_CRI_004093                       4G                  2G
# 686    G_CRI_001782                       4G                  2G
# 3133   G_CRI_002536                       4G                None
# 81     G_CRI_004320                       4G                  2G
# 2577   G_CRI_001585                       4G                  2G
#
#      giga_school_id 4g_coverage (Facebook) 4g_coverage (ITU)
# 498    G_CRI_001712                    YES                NO
# 309    G_CRI_000741                    YES                NO
# 1394   G_CRI_002079                    YES                NO
# 3730   G_CRI_003988                    YES                NO
# 1152   G_CRI_003719                    YES                NO
# 2478   G_CRI_002118                    YES                NO
# 4410   G_CRI_003430                    YES                NO
# 3025   G_CRI_001125                    YES                NO
# 1038   G_CRI_004196                    YES                NO
# 3447   G_CRI_002570                    YES                NO
#
#      giga_school_id coverage (Facebook) coverage (ITU)
# 1443   G_CRI_004225                 YES             NO
# 719    G_CRI_004170                 YES             NO
# 805    G_CRI_002561                 YES             NO
# 3136   G_CRI_003307                 YES             NO
# 2814   G_CRI_002607                 YES             NO
# 4389   G_CRI_004411                 YES             NO
# 3511   G_CRI_002198                 YES             NO
# 3618   G_CRI_000829                 YES             NO
# 2791   G_CRI_002408                 YES             NO
# 4213   G_CRI_001344                 YES             NO
#
#      giga_school_id 2g_coverage (Facebook) 2g_coverage (ITU)
# 655    G_CRI_003876                    YES                NO
# 2010   G_CRI_000747                    YES                NO
# 3179   G_CRI_002847                    YES                NO
# 1485   G_CRI_003550                    YES                NO
# 2482   G_CRI_002520                    YES                NO
# 2598   G_CRI_000579                    YES                NO
# 3571   G_CRI_000505                    YES                NO
# 2713   G_CRI_000554                    YES                NO
# 499    G_CRI_001886                    YES                NO
# 502    G_CRI_002165                    YES                NO
#
#      giga_school_id 3g_coverage (Facebook) 3g_coverage (ITU)
# 3943   G_CRI_003936                    YES                NO
# 806    G_CRI_002634                    YES                NO
# 2926   G_CRI_001136                    YES                NO
# 1584   G_CRI_001887                    YES                NO
# 1563   G_CRI_003267                    YES                NO
# 4130   G_CRI_003286                    YES                NO
# 1624   G_CRI_001219                    YES                NO
# 694    G_CRI_004423                    YES                NO
# 1166   G_CRI_002498                    YES                NO
# 284    G_CRI_001778                    YES                NO
#
#
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns  Rows
# 0  Facebook        6  4598
# 1      GSMA        6  4598
#
# Column Summary
# --------------
#
# Number of columns in common: 6
# Number of columns in Facebook but not in GSMA: 0
# Number of columns in GSMA but not in Facebook: 0
#
# Row Summary
# -----------
#
# Matched on: giga_school_id
# Any duplicates on match values: No
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 4,598
# Number of rows in Facebook but not in GSMA: 0
# Number of rows in GSMA but not in Facebook: 0
#
# Number of rows with some compared columns unequal: 16
# Number of rows with all compared columns equal: 4,582
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 1
# Number of columns compared with all values equal: 5
# Total number of values which compare unequal: 16
#
# Columns with Unequal Values or Types
# ------------------------------------
#
#           Column Facebook dtype GSMA dtype  # Unequal  Max Diff  # Null Diff
# 0  coverage_type         object     object         16         0            0
#
# Sample Rows with Unequal Values
# -------------------------------
#
#      giga_school_id coverage_type (Facebook) coverage_type (GSMA)
# 2058   G_CRI_004180                       4G                   3G
# 4514   G_CRI_003912                       4G                 None
# 1909   G_CRI_004181                       4G                   3G
# 2856   G_CRI_004414                       4G                 None
# 107    G_CRI_003915                       4G                   3G
# 1182   G_CRI_004420                       4G                 None
# 2467   G_CRI_003883                       4G                   3G
# 1062   G_CRI_004153                       4G                   3G
# 189    G_CRI_001723                       4G                   3G
# 405    G_CRI_001736                       4G                   3G

# %%
# merging and selecting the most frequent values across the sources on each row and colunm
# creating a master coverage dataset and merging with the master school location dataset

# %%
import statistics as stats
df_c = pd.concat([d_fc,d_ec,d_it])
coverage = df_c.groupby(['giga_school_id'],as_index=False).agg(lambda x:x.value_counts().index[0])
coverage['coverage_type'] = coverage.apply((lambda x: coverage_type(x)),axis=1)
#coverage = df_c.groupby(['giga_school_id'],as_index=False).agg(lambda x: stats.mode(x)[0][0])

# %%
coverage.head()
# Out:
#   giga_school_id coverage coverage_type 2G_coverage 3G_coverage 4G_coverage
# 0   G_CRI_000001      YES            4G         YES         YES         YES
# 1   G_CRI_000002      YES            4G         YES         YES         YES
# 2   G_CRI_000003      YES            4G         YES         YES         YES
# 3   G_CRI_000004      YES            4G         YES         YES         YES
# 4   G_CRI_000005      YES            4G         YES         YES         YES

# %%
coverage[coverage['coverage']=='NO'].head(10)
# Out:
# Empty DataFrame
# Columns: [giga_school_id, coverage, coverage_type, 2G_coverage, 3G_coverage, 4G_coverage]
# Index: []

# %%
#coverage.loc[coverage['coverage_type'] == 'None', 'coverage_type'] = d_gs.coverage_type

# %%
''''
#Main
import statistics as stats
df_c = pd.concat([d_fc,d_ec,d_it])
coverage = df_c.groupby(['giga_school_id'],as_index=False).agg(lambda x: stats.mode(x)[0][0])
coverage.loc[coverage['coverage'] == 'Y', 'coverage'] = 'YES'
coverage.loc[coverage['coverage'] == 'N', 'coverage'] = 'NO'
coverage.loc[coverage['2G_coverage'] == 'Y', '2G_coverage'] = 'YES'
coverage.loc[coverage['2G_coverage'] == 'N', '2G_coverage'] = 'NO'
coverage.loc[coverage['3G_coverage'] == 'Y', '3G_coverage'] = 'YES'
coverage.loc[coverage['3G_coverage'] == 'N', '3G_coverage'] = 'NO'
coverage.loc[coverage['4G_coverage'] == 'Y', '4G_coverage'] = 'YES'
coverage.loc[coverage['4G_coverage'] == 'N', '4G_coverage'] = 'NO'

coverage.loc[coverage['coverage_type'] == '4', 'coverage_type'] = '4G'
coverage.loc[coverage['coverage_type'] == '3', 'coverage_type'] = '3G'
coverage.loc[coverage['coverage_type'] == '2', 'coverage_type'] = '2G'
coverage.loc[coverage['coverage_type'] == 'N', 'coverage_type'] = 'None'

coverage.loc[coverage['coverage_type'] == 'None', 'coverage_type'] = d_gs.coverage_type
# Out:
#   File "<ipython-input-106-4b2080777d29>", line 20
#     coverage.loc[coverage['coverage_type'] == 'None', 'coverage_type'] = d_gs.coverage_type
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
master.head()
# Out:
#                                    uuid     country      source  school_id  \
# 0  4311e67f-667b-35b3-b27b-5eff74a4bfad  Costa Rica  government       3945
# 1  edf0833e-ad77-32b0-8e80-0c29feceb0a1  Costa Rica  government       3946
# 2  561d425c-4e7a-37ab-b96f-a8781095cb82  Costa Rica  government       3948
# 3  73c10e7a-a1d7-37ae-b703-9a1058d1e958  Costa Rica  government       3982
# 4  8a870607-dcf8-3ea4-b356-0ada8e5124bb  Costa Rica  government       3997
#
#   giga_school_id                               name education_level  \
# 0   G_CRI_000001     LICEO NAPOLEON QUESADA SALAZAR       secondary
# 1   G_CRI_000002        LICEO MAURO FERNANDEZ ACUNA       secondary
# 2   G_CRI_000003         LICEO ROBERTO BRENES MESEN       secondary
# 3   G_CRI_000004  LICEO MONSENOR RUBEN ODIO HERRERA       secondary
# 4   G_CRI_000005                     LICEO PURISCAL       secondary
#
#    student_count connectivity type_connectivity  connectivity_speed  \
# 0         1164.0          YES                FO                60.0
# 1          881.0          YES                FO                40.0
# 2          874.0          YES              ADSL                10.0
# 3         1519.0          YES                FO               105.0
# 4          930.0          YES                FO                60.0
#
#   electricity_availability       lat        lon
# 0                      Yes  9.943509 -84.061523
# 1                      Yes  9.957542 -84.080789
# 2                      Yes  9.921953 -84.103735
# 3                      Yes  9.901808 -84.067074
# 4                      Yes  9.847161 -84.313211

# %%
master_w_coverage = master.merge(coverage, how="left", on=["giga_school_id"])
master_w_coverage.to_csv('./data/CR_master_w_coverage.csv', encoding='utf-8')
master_w_coverage_connectivity = master_w_coverage.copy()
#master_w_coverage_connectivity['connectivity_availability'] = np.where((master_w_coverage_connectivity['connectivity_type'] != 'None'), 'YES', 'NO')
master_w_coverage_connectivity.loc[master_w_coverage_connectivity['coverage'] == 'NO', 'connectivity'] = 'NO'
master_w_coverage_connectivity.loc[master_w_coverage_connectivity['coverage'] == 'NO', 'coverage_type'] = 'None'
master_w_coverage_connectivity.loc[master_w_coverage_connectivity['coverage_type'] == 'None', 'coverage'] = 'NO'
master_w_coverage_connectivity.loc[master_w_coverage_connectivity['coverage_type'] == 'None', 'coverage_type'] = 'no coverage'
master_w_coverage_connectivity.to_csv('./data/CR_master_w_coverage_connectivity.csv', encoding='utf-8')

# %%
master_w_coverage.head(2)
# Out:
#                                    uuid     country      source  school_id  \
# 0  4311e67f-667b-35b3-b27b-5eff74a4bfad  Costa Rica  government       3945
# 1  edf0833e-ad77-32b0-8e80-0c29feceb0a1  Costa Rica  government       3946
#
#   giga_school_id                            name education_level  \
# 0   G_CRI_000001  LICEO NAPOLEON QUESADA SALAZAR       secondary
# 1   G_CRI_000002     LICEO MAURO FERNANDEZ ACUNA       secondary
#
#    student_count connectivity type_connectivity  connectivity_speed  \
# 0         1164.0          YES                FO                60.0
# 1          881.0          YES                FO                40.0
#
#   electricity_availability       lat        lon coverage coverage_type  \
# 0                      Yes  9.943509 -84.061523      YES            4G
# 1                      Yes  9.957542 -84.080789      YES            4G
#
#   2G_coverage 3G_coverage 4G_coverage
# 0         YES         YES         YES
# 1         YES         YES         YES

# %%
master_w_coverage_connectivity[master_w_coverage_connectivity['coverage_type']=='no coverage'].head(10)
# Out:
# Empty DataFrame
# Columns: [uuid, country, source, school_id, giga_school_id, name, education_level, student_count, connectivity, type_connectivity, connectivity_speed, electricity_availability, lat, lon, coverage, coverage_type, 2G_coverage, 3G_coverage, 4G_coverage]
# Index: []

# %%
master_w_coverage_connectivity.head()
# Out:
#                                    uuid     country      source  school_id  \
# 0  4311e67f-667b-35b3-b27b-5eff74a4bfad  Costa Rica  government       3945
# 1  edf0833e-ad77-32b0-8e80-0c29feceb0a1  Costa Rica  government       3946
# 2  561d425c-4e7a-37ab-b96f-a8781095cb82  Costa Rica  government       3948
# 3  73c10e7a-a1d7-37ae-b703-9a1058d1e958  Costa Rica  government       3982
# 4  8a870607-dcf8-3ea4-b356-0ada8e5124bb  Costa Rica  government       3997
#
#   giga_school_id                               name education_level  \
# 0   G_CRI_000001     LICEO NAPOLEON QUESADA SALAZAR       secondary
# 1   G_CRI_000002        LICEO MAURO FERNANDEZ ACUNA       secondary
# 2   G_CRI_000003         LICEO ROBERTO BRENES MESEN       secondary
# 3   G_CRI_000004  LICEO MONSENOR RUBEN ODIO HERRERA       secondary
# 4   G_CRI_000005                     LICEO PURISCAL       secondary
#
#    student_count connectivity type_connectivity  connectivity_speed  \
# 0         1164.0          YES                FO                60.0
# 1          881.0          YES                FO                40.0
# 2          874.0          YES              ADSL                10.0
# 3         1519.0          YES                FO               105.0
# 4          930.0          YES                FO                60.0
#
#   electricity_availability       lat        lon coverage coverage_type  \
# 0                      Yes  9.943509 -84.061523      YES            4G
# 1                      Yes  9.957542 -84.080789      YES            4G
# 2                      Yes  9.921953 -84.103735      YES            4G
# 3                      Yes  9.901808 -84.067074      YES            4G
# 4                      Yes  9.847161 -84.313211      YES            4G
#
#   2G_coverage 3G_coverage 4G_coverage
# 0         YES         YES         YES
# 1         YES         YES         YES
# 2         YES         YES         YES
# 3         YES         YES         YES
# 4         YES         YES         YES

# %%
master_w_coverage_connectivity['coverage'].value_counts()
# Out:
# YES    4598
# Name: coverage, dtype: int64
